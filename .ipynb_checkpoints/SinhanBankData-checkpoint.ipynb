# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd 
import numpy as np

# %%
# data1 = pd.read_excel("C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\finance_data201903(1)\\finance_data201903.xlsx")
# data2 = pd.read_excel("C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\finance_data201903(1)\\finance_data201909.xlsx")
# data3 = pd.read_excel("C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\finance_data201903(1)\\finance_data202003.xlsx")
# data4 = pd.read_excel("C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\finance_data201903(1)\\finance_data202009.xlsx")
# data5 = pd.read_excel("C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\finance_data201903(1)\\finance_data202103.xlsx")

# %%
# data1

# %% [markdown]
# # 데이터 통합하기

# %%
# print(data1.shape)
# print(data2.shape)
# print(data3.shape)
# print(data4.shape)
# print(data5.shape)

# %%
# 203490+204949+208936+210307+211886

# %% [markdown]
# 서울 내 행정동별 데이터임에도 불구하고, 분기별로 데이터의 갯수가 다른점..
# 이유에 대해 알아볼 필요성이 있을것 같습니다.

# %%
# data1.info()

# %%
# print(len(data1["법정동"].unique()))
# print(len(data2["법정동"].unique()))
# print(len(data3["법정동"].unique()))
# print(len(data4["법정동"].unique()))
# print(len(data5["법정동"].unique()))

# %%
# columns = data1.columns
# columns

# %%
# total_data = pd.DataFrame(columns=columns)
# for i in [data1, data2, data3, data4, data5]:
#     total_data = total_data.append(i)

# %%
# total_data

# %%
# total_data.to_excel('../finance_data201903(1)/total.xlsx')

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 

# 한글폰트 설정 
plt.rcParams['font.family'] = 'Malgun Gothic'
# 마이너스 폰트 깨짐 방지 
plt.rcParams['axes.unicode_minus'] = False

# %%
total_data = pd.read_excel('../finance_data201903(1)/total.xlsx')

# %%
total_data
# Out:
#            기준년월  지역구     법정동코드  법정동          집계구코드  나이  성별  직장인여부  급여입금  \
# 0        201903  강남구  11680101  역삼동  1123064010001   2   1      0     0
# 1        201903  강남구  11680101  역삼동  1123064010001   2   2      0     0
# 2        201903  강남구  11680101  역삼동  1123064010001   3   1      0     0
# 3        201903  강남구  11680101  역삼동  1123064010001   3   2      0     0
# 4        201903  강남구  11680101  역삼동  1123064010001   4   1      0     0
# ...         ...  ...       ...  ...            ...  ..  ..    ...   ...
# 1039563  202103  중랑구  11260106  신내동  1107070010802   5   2      0     0
# 1039564  202103  중랑구  11260106  신내동  1107070010802   6   1      0     0
# 1039565  202103  중랑구  11260106  신내동  1107070010802   6   2      0     0
# 1039566  202103  중랑구  11260106  신내동  1107070010802   7   1      0     0
# 1039567  202103  중랑구  11260106  신내동  1107070010802   7   2      0     0
#
#          가맹점매출입금    연금입금    총소비금액    총수신금액     예적금금액  신탁금액  수익증권금액  신용대출금액  \
# ...

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039568 entries, 0 to 1039567
# Data columns (total 20 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   기준년월      1039568 non-null  int64
#  1   지역구       1039568 non-null  object
#  2   법정동코드     1039568 non-null  int64
#  3   법정동       1039568 non-null  object
#  4   집계구코드     1039568 non-null  int64
#  5   나이        1039568 non-null  int64
#  6   성별        1039568 non-null  int64
#  7   직장인여부     1039568 non-null  int64
#  8   급여입금      1039568 non-null  int64
#  9   가맹점매출입금   1039568 non-null  int64
#  10  연금입금      1039568 non-null  int64
#  11  총소비금액     1039568 non-null  int64
#  12  총수신금액     1039568 non-null  int64
#  13  예적금금액     1039568 non-null  int64
#  14  신탁금액      1039568 non-null  int64
#  15  수익증권금액    1039568 non-null  int64
#  16  신용대출금액    1039568 non-null  int64
#  17  담보대출금액    1039568 non-null  int64
#  18  주택대출금액    1039568 non-null  int64
# ...

# %%
total_data["기준년월"] = pd.to_datetime(total_data["기준년월"],format="%Y%m")
total_data
# Out:
#               기준년월  지역구     법정동코드  법정동          집계구코드  나이  성별  직장인여부  급여입금  \
# 0       2019-03-01  강남구  11680101  역삼동  1123064010001   2   1      0     0
# 1       2019-03-01  강남구  11680101  역삼동  1123064010001   2   2      0     0
# 2       2019-03-01  강남구  11680101  역삼동  1123064010001   3   1      0     0
# 3       2019-03-01  강남구  11680101  역삼동  1123064010001   3   2      0     0
# 4       2019-03-01  강남구  11680101  역삼동  1123064010001   4   1      0     0
# ...            ...  ...       ...  ...            ...  ..  ..    ...   ...
# 1039563 2021-03-01  중랑구  11260106  신내동  1107070010802   5   2      0     0
# 1039564 2021-03-01  중랑구  11260106  신내동  1107070010802   6   1      0     0
# 1039565 2021-03-01  중랑구  11260106  신내동  1107070010802   6   2      0     0
# 1039566 2021-03-01  중랑구  11260106  신내동  1107070010802   7   1      0     0
# 1039567 2021-03-01  중랑구  11260106  신내동  1107070010802   7   2      0     0
#
# ...

# %% [markdown]
# ## 연도별 추이 분석하기

# %%
total_data.columns
# Out:
# Index(['기준년월', '지역구', '법정동코드', '법정동', '집계구코드', '나이', '성별', '직장인여부', '급여입금',
#        '가맹점매출입금', '연금입금', '총소비금액', '총수신금액', '예적금금액', '신탁금액', '수익증권금액',
#        '신용대출금액', '담보대출금액', '주택대출금액', '전세자금대출금액'],
#       dtype='object')

# %%
연도별합 = pd.DataFrame(total_data.groupby(['기준년월'])['급여입금',
       '가맹점매출입금', '연금입금', '총소비금액', '총수신금액', '예적금금액', '신탁금액', '수익증권금액',
       '신용대출금액', '담보대출금액', '주택대출금액', '전세자금대출금액'].sum())
# Out:
# <ipython-input-39-06b0331423d3>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   연도별합 = pd.DataFrame(total_data.groupby(['기준년월'])['급여입금',

# %%
연도별합 = 연도별합.reset_index()

# %%
연도별합
# Out:
#         기준년월         급여입금    가맹점매출입금        연금입금         총소비금액         총수신금액  \
# 0 2019-03-01  20805831936  839528182  3468426855  238172562581  820200502005
# 1 2019-09-01  24030015451  617874131  3671430507  258654169165  831807261078
# 2 2020-03-01  26010720741  355103097  4262326258  229126078465  888404158235
# 3 2020-09-01  28529963374  358161722  4275323633  250485855769  943267915407
# 4 2021-03-01  29748774403  546693074  4864847159  265522363855  958008616508
#
#           예적금금액          신탁금액       수익증권금액        신용대출금액        담보대출금액  \
# 0  740459280020  112739636608  48242850312   53225962125  359931962833
# 1  719690512899  112645519236  50117105400   63295622630  356266863033
# 2  762400753741  120060683681  45681640499   82010553283  385335151473
# 3  761119280871  105966056127  46813662154  102860625867  435036081209
# 4  730454274324  101203028253  41114836231  121947012223  505349568461
#
#         주택대출금액     전세자금대출금액
# 0  27224709815  31469989827
# ...

# %%
# plt.figure(figsize=(15,15))

# sns.lineplot(data = 연도별합, x='기준년월',y='급여입금')
# plt.xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'],['201903','201909','202003','202009','202103'])

# %%
# plt.figure(figsize=(15,15))

# sns.lineplot(data = 연도별합, x='기준년월',y='가맹점매출입금')
# plt.xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'],['201903','201909','202003','202009','202103'])

# %%
fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6), (ax7,ax8), (ax9,ax10), (ax11,ax12)) = plt.subplots(nrows=6, ncols=2,figsize=(50,50))

sns.lineplot(data = 연도별합, x='기준년월',y='급여입금', ax=ax1)
ax1.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax1.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='가맹점매출입금',ax=ax2)
ax2.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax2.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='연금입금',ax=ax3)
ax3.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax3.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='총소비금액',ax=ax4)
ax4.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax4.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='총수신금액',ax=ax5)
ax5.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax5.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='예적금금액',ax=ax6)
ax6.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax6.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='신탁금액',ax=ax7)
ax7.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax7.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='수익증권금액',ax=ax8)
ax8.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax8.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='신용대출금액',ax=ax9)
ax9.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax9.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='담보대출금액',ax=ax10)
ax10.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax10.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='주택대출금액',ax=ax11)
ax11.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax11.set_xticklabels(['201903','201909','202003','202009','202103'])

sns.lineplot(data = 연도별합, x='기준년월',y='전세자금대출금액',ax=ax12)
ax12.set_xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'])
ax12.set_xticklabels(['201903','201909','202003','202009','202103'])
# Out:
# [Text(17956.0, 0, '201903'),
#  Text(18140.0, 0, '201909'),
#  Text(18322.0, 0, '202003'),
#  Text(18506.0, 0, '202009'),
#  Text(18687.0, 0, '202103')]

# %% [markdown]
# 1. 급여입금 - 신한은행 계좌를 통해 입금되는 급여입금의 총액은 꾸준한 증가 추이를 보인다. 하지만, 20년 3월과 9월에는 증가 폭이 소폭 감소함을 확인할 수 있었다.
# 2. 가맹점 매출입금 - 가맹점 매출입금은 이전부터 감소세를 겪던 가맹점 매출입금은 COVID-19 의 확산 1년차인 2020년 3월 9월에 최 저점을 보이고 이후 증가함을 볼 수 있다.
# 3. 연금입금 - 연금입금액은 코로나가 확산된 시점 이후로 가파른 상승폭을 보입니다.
# 4. 총 소비금액 - 총 소비금액의 변동은 큰 특징을 보이지는 않지만, 20년 3월 큰 폭으로 감소한 후 다시 증가하는 추세를 보입니다.
# 5. 총 수신금액 - 꾸준히 증가하는 모습이다.
# 6. 예적금금액 -
# 7. 신탁금액 -
# 8. 수익증권금액 -
# 9. 신용대출액 -
# 10. 담보대출금액 -
# 11. 주택대출금액 -
# 12. 전세자금 대출금액 -

# %%
total_data['기준년월'].unique()
# Out:
# array(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
기준년월별_예적금금액변동 = pd.DataFrame(total_data.groupby(['기준년월','지역구'])['예적금금액'].sum())

# %%
기준년월별_예적금금액변동 = 기준년월별_예적금금액변동.reset_index()
기준년월별_예적금금액변동
# Out:
#           기준년월  지역구        예적금금액
# 0   2019-03-01  강남구  66780046022
# 1   2019-03-01  강동구  29806888712
# 2   2019-03-01  강북구  12628997836
# 3   2019-03-01  강서구  41318295318
# 4   2019-03-01  관악구  31773566547
# ..         ...  ...          ...
# 120 2021-03-01  용산구  22655128365
# 121 2021-03-01  은평구  31002213340
# 122 2021-03-01  종로구  11234418377
# 123 2021-03-01   중구  11492089990
# 124 2021-03-01  중랑구  24158110464
#
# [125 rows x 3 columns]

# %%
기준년월별_예적금금액변동["기준년월"] = pd.to_datetime(기준년월별_예적금금액변동["기준년월"],format="%Y%m")

# %%
기준년월별_예적금금액변동["기준년월"].unique()
# Out:
# array(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
plt.figure(figsize=(15,15))

sns.lineplot(data = 기준년월별_예적금금액변동, x='기준년월',y='예적금금액',hue='지역구')
plt.xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
       '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
       '2021-03-01T00:00:00.000000000'],['201903','201909','202003','202009','202103'])
# Out:
# ([<matplotlib.axis.XTick at 0x1add03c7790>,
# ...
#  [Text(17956.0, 0, '201903'),
#   Text(18140.0, 0, '201909'),
#   Text(18322.0, 0, '202003'),
#   Text(18506.0, 0, '202009'),
#   Text(18687.0, 0, '202103')])

# %% [markdown]
# 전체적으로 예적금 금액의 변동이 20년 3월을 기점으로 변동함을 볼 수 있습니다.
# 다만, 지역별로 금액의 차이가 커, 나누어 살펴보는것이 좋을 것 같습니다.

# %%
기준년월별_예적금금액변동['예적금금액'].describe()
# Out:
# count    1.250000e+02
# mean     2.971299e+10
# std      1.420267e+10
# min      1.123442e+10
# 25%      2.208864e+10
# 50%      2.637882e+10
# 75%      3.388205e+10
# max      6.983828e+10
# Name: 예적금금액, dtype: float64

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(nrows=4, figsize=(50,50))

sns.lineplot(data = 기준년월별_예적금금액변동.loc[기준년월별_예적금금액변동['예적금금액']< 2.208864e+10], x='기준년월',y='예적금금액',hue='지역구', ax=ax1)
sns.lineplot(data = 기준년월별_예적금금액변동.loc[(기준년월별_예적금금액변동['예적금금액']> 2.208864e+10)  & (기준년월별_예적금금액변동['예적금금액'] < 2.637882e+10)], x='기준년월',y='예적금금액',hue='지역구', ax=ax2)
sns.lineplot(data = 기준년월별_예적금금액변동.loc[(기준년월별_예적금금액변동['예적금금액']> 2.637882e+10) & (기준년월별_예적금금액변동['예적금금액'] < 3.388205e+10)], x='기준년월',y='예적금금액',hue='지역구', ax=ax3)
sns.lineplot(data = 기준년월별_예적금금액변동.loc[기준년월별_예적금금액변동['예적금금액']> 3.388205e+10], x='기준년월',y='예적금금액',hue='지역구',ax=ax4)

# fig.xticks(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'],['201903','201909','202003','202009','202103'])



ax1.set_title("0~25%")
ax2.set_title("25~50%")
ax3.set_title("50~75%")
ax4.set_title("75~100%")
# Out:
# Text(0.5, 1.0, '75~100%')

# %%
기준년월별_예적금금액변동.loc[기준년월별_예적금금액변동['예적금금액']< 2.208864e+10]
# Out:
#           기준년월   지역구        예적금금액
# 2   2019-03-01   강북구  12628997836
# 5   2019-03-01   광진구  22088637234
# 7   2019-03-01   금천구  14038956979
# 10  2019-03-01  동대문구  17049654005
# 13  2019-03-01  서대문구  17746538008
# 22  2019-03-01   종로구  12037205725
# 23  2019-03-01    중구  12504355426
# 27  2019-09-01   강북구  12210394623
# 30  2019-09-01   광진구  21955450593
# 32  2019-09-01   금천구  13216270712
# 35  2019-09-01  동대문구  16512283290
# 38  2019-09-01  서대문구  17737556035
# 47  2019-09-01   종로구  11433874928
# 48  2019-09-01    중구  11754469514
# 52  2020-03-01   강북구  13347667539
# 57  2020-03-01   금천구  13830304429
# 60  2020-03-01  동대문구  16693788765
# 63  2020-03-01  서대문구  18300665444
# 72  2020-03-01   종로구  12322264037
# 73  2020-03-01    중구  12250101586
# 77  2020-09-01   강북구  12956652371
# 82  2020-09-01   금천구  14253026457
# 85  2020-09-01  동대문구  17592269076
# 88  2020-09-01  서대문구  18130388479
# 97  2020-09-01   종로구  12101045358
# 98  2020-09-01    중구  12190255809
# ...

# %% [markdown]
# 문제점1. x축 설정
# 문제점2. 해당 방식을 통한 필터링 적용시 같은 구여도 데이터가 나뉘어짐

# %% [markdown]
# ## 지역별 분석

# %%
total_data['지역구'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
total_data['기준년월'].unique()
# Out:
# array(['2019-03-01T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
print(len(total_data.loc[total_data['기준년월']=='2019-03-01T00:00:00.000000000']['법정동'].unique()))
print(len(total_data.loc[total_data['기준년월']=='2019-09-01T00:00:00.000000000']['법정동'].unique()))
print(len(total_data.loc[total_data['기준년월']=='2020-03-01T00:00:00.000000000']['법정동'].unique()))
print(len(total_data.loc[total_data['기준년월']=='2020-09-01T00:00:00.000000000']['법정동'].unique()))
print(len(total_data.loc[total_data['기준년월']=='2021-03-01T00:00:00.000000000']['법정동'].unique()))
# Out:
# 448
# 448
# 449
# 450
# 450

# %%
total_data.columns
# Out:
# Index(['기준년월', '지역구', '법정동코드', '법정동', '집계구코드', '나이', '성별', '직장인여부', '급여입금',
#        '가맹점매출입금', '연금입금', '총소비금액', '총수신금액', '예적금금액', '신탁금액', '수익증권금액',
#        '신용대출금액', '담보대출금액', '주택대출금액', '전세자금대출금액'],
#       dtype='object')

# %%
temp = total_data.groupby(["기준년월","지역구"])['급여입금',
       '가맹점매출입금', '연금입금', '총소비금액', '총수신금액', '예적금금액', '신탁금액', '수익증권금액',
       '신용대출금액', '담보대출금액', '주택대출금액', '전세자금대출금액'].sum().reset_index()
# Out:
# <ipython-input-30-5b29d61ec8cb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   temp = total_data.groupby(["기준년월","지역구"])['급여입금',

# %%
temp
# Out:
#           기준년월  지역구        급여입금    가맹점매출입금       연금입금        총소비금액  \
# 0   2019-03-01  강남구  2343217980  173412507  365400221  16626306023
# 1   2019-03-01  강동구   540355743   84242683  118722105   9915572200
# 2   2019-03-01  강북구   116142327    5653934   82524896   6551953668
# 3   2019-03-01  강서구  1897094564   10559121  267245011  14346285799
# 4   2019-03-01  관악구  1379134435          0  141147592  11678424939
# ..         ...  ...         ...        ...        ...          ...
# 120 2021-03-01  용산구  1006457474   18695544  167562448   7584354899
# 121 2021-03-01  은평구   628699921   10263394  232881278  12324084480
# 122 2021-03-01  종로구   418766877    5493582   77978619   4491112168
# 123 2021-03-01   중구   415609679   43605712   74340911   4155109598
# 124 2021-03-01  중랑구   398638829    3463566  204467522  10344237289
#
#            총수신금액        예적금금액         신탁금액       수익증권금액      신용대출금액  \
# 0    66265751376  66780046022  29969789931  13146476407  8398123775
# ...

# %% [markdown]
# 관악구의 19년 3월 가맹점 매출입금 총액이 0원인 점은 해당 데이터의 문제점을 드러냅니다.
# 이 뿐만 아니라 신한은행 계좌를 대상으로 하는 데이터이기 때문에 데이터 내부의 문제점이 다소 존재합니다.

# %%
temp.loc[temp["지역구"] == '관악구']
# Out:
#           기준년월  지역구        급여입금  가맹점매출입금       연금입금        총소비금액        총수신금액  \
# 4   2019-03-01  관악구  1379134435        0  141147592  11678424939  36141077411
# 29  2019-09-01  관악구  1550294863  2902121  143379416  12730204800  36719811395
# 54  2020-03-01  관악구  1591781266  1804063  156851375  11337188245  39035156150
# 79  2020-09-01  관악구  1675264766        0  170352323  12291019663  41386258623
# 104 2021-03-01  관악구  1737944500  1479589  186800695  13089682224  41714561571
#
#            예적금금액       신탁금액     수익증권금액      신용대출금액       담보대출금액     주택대출금액  \
# 4    31773566547  746121608  297621929  1361769862   7048991333  390791675
# 29   31128610044  760971219  262678989  1779225755   9052867002  384407508
# 54   33030432515  755720867  267819076  2228756037  13488957193  407973039
# 79   34018107424  563244455  297962253  1997500731  15006684424  391701763
# 104  32083154867  633545897  185398635  2886727277  18978291071  380601405
#
#        전세자금대출금액
# 4     785667972
# ...

# %%
total_data.groupby(by=['기준년월','법정동'])['담보대출금액','주택대출금액','전세자금대출금액'].sum()
# Out:
# <ipython-input-33-beba155f7846>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_data.groupby(by=['기준년월','법정동'])['담보대출금액','주택대출금액','전세자금대출금액'].sum()
#                      담보대출금액      주택대출금액   전세자금대출금액
# 기준년월       법정동
# 2019-03-01 가락동   3005420249  1292471991          0
#            가리봉동    46778937           0          0
#            가산동   1660733087   197966836  600734048
#            가양동   4083678075   307255164  925680887
#            가회동     64181551           0          0
# ...                     ...         ...        ...
# 2021-03-01 효창동    957718761           0  124821157
#            후암동     78772917           0          0
#            휘경동    328265070           0          0
#            흑석동   3640971169  1682212085          0
#            흥인동    948416845           0          0
#
# [2245 rows x 3 columns]

# %%
import folium

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]
# 내방 = [37.17571, 126.50212]

Map = folium.Map(location=center, zoom_start=11)
# Map = folium.Map(location=center, zoom_start=11,tiles='Stamen Toner')
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 성별 분석

# %% [markdown]
# ##
